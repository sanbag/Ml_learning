# %%
import pandas as pd

# %%
df = pd.read_csv('wage.csv')

# %%
df.tail()
# Out:
#          wage  hours   IQ  educ  exper  tenure  age  married  black  meduc  \
# 930   52000.0     40   79    16      6       1   30        1      1   11.0
# 931  120200.0     40  102    13     10       3   31        1      0    8.0
# 932   53800.0     45   77    12     12      10   28        1      1    7.0
# 933   87300.0     44  109    12     12      12   28        1      0    NaN
# 934  100000.0     40  107    12     17      18   35        1      0    NaN
#
#      feduc
# 930    NaN
# 931    6.0
# 932    NaN
# 933   11.0
# 934    NaN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 935 entries, 0 to 934
# Data columns (total 11 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   wage     935 non-null    float64
#  1   hours    935 non-null    int64
#  2   IQ       935 non-null    int64
#  3   educ     935 non-null    int64
#  4   exper    935 non-null    int64
#  5   tenure   935 non-null    int64
#  6   age      935 non-null    int64
#  7   married  935 non-null    int64
#  8   black    935 non-null    int64
#  9   meduc    857 non-null    float64
#  10  feduc    741 non-null    float64
# dtypes: float64(3), int64(8)
# memory usage: 80.5 KB

# %%
df.value_counts()
# Out:
# wage      hours  IQ   educ  exper  tenure  age  married  black  meduc  feduc
# 11500.0   50     108  12    9      3       29   1        0      10.0   11.0     1
# 107500.0  40     103  12    17     10      33   1        0      11.0   11.0     1
# 107600.0  38     106  12    19     20      36   1        0      12.0   9.0      1
#           45     105  12    5      8       31   0        0      16.0   17.0     1
# 108100.0  40     92   13    8      2       30   1        0      12.0   10.0     1
#                                                                                ..
# 77400.0   40     94   12    20     4       37   1        0      12.0   7.0      1
# 77900.0   40     84   12    9      6       30   1        0      8.0    12.0     1
# 78100.0   40     89   11    13     10      30   1        0      9.0    8.0      1
#           50     112  12    8      10      30   1        0      12.0   8.0      1
# ...
